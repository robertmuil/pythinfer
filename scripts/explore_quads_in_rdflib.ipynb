# %%
from pathlib import Path

PROJ_DIR  = Path.cwd().parent
print(f"{PROJ_DIR=}")
print(f"{PROJ_DIR.as_uri()=}")
# Out:
# PROJ_DIR=PosixPath('/home/robert/git/pythinfer')
# PROJ_DIR.as_uri()='file:///home/robert/git/pythinfer'

# %%
from rdflib import Dataset, Graph

DATA_DIR = PROJ_DIR / "example_projects" / "eg1-ancestors"

DATA_FILES = list(DATA_DIR.glob("*-data.ttl"))
VOCAB_INTERNAL_FILES = list(DATA_DIR.glob("*-model.ttl"))

ds = Dataset()


for f in VOCAB_INTERNAL_FILES + DATA_FILES:
    g = ds.graph(identifier=f.name)
    g.parse(f, format="turtle")
    print(f"Loaded {len(g)} triples into graph {g.identifier} from {f.name}")
# Out:
# Loaded 22 triples into graph ancestors-model.ttl from ancestors-model.ttl
# Loaded 9 triples into graph ancestors-data.ttl from ancestors-data.ttl

# %%
print(ds.serialize(format="trig"))
# Out:
# @prefix ex: <http://example.org/ancestor/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# <ancestors-model.ttl> {
#     ex:childOf rdfs:label "child of" ;
#         owl:inverseOf ex:parentOf .
#
#     ex:descendantOf rdfs:label "descendant of" ;
#         owl:inverseOf ex:ancestorOf .
#
#     ex:ancestorOf a owl:ObjectProperty ;
#         rdfs:label "ancestor of" ;
#         rdfs:domain ex:Person ;
#         rdfs:range ex:Person ;
#         owl:propertyChainAxiom _:n9350344ddcec40f28f670544494de786b1,
#             _:n9350344ddcec40f28f670544494de786b3 .
#
#     ex:parentOf a owl:ObjectProperty ;
#         rdfs:label "parent of" ;
#         rdfs:domain ex:Person ;
#         rdfs:range ex:Person .
#
#     ex:Person a owl:Class ;
#         rdfs:label "Person" .
#
#     _:n9350344ddcec40f28f670544494de786b1 rdf:first ex:parentOf ;
#         rdf:rest _:n9350344ddcec40f28f670544494de786b2 .
#
#     _:n9350344ddcec40f28f670544494de786b2 rdf:first ex:ancestorOf ;
#         rdf:rest () .
#
#     _:n9350344ddcec40f28f670544494de786b3 rdf:first ex:parentOf ;
#         rdf:rest () .
# }
#
# <ancestors-data.ttl> {
#     ex:Alice a ex:Person ;
#         ex:parentOf ex:Bob,
#             ex:Carol .
#
#     ex:Bob a ex:Person ;
#         ex:parentOf ex:David .
#
#     ex:Carol a ex:Person ;
#         ex:parentOf ex:Eve .
#
#     ex:David a ex:Person .
#
#     ex:Eve a ex:Person .
# }

# %%
for g in ds.graphs():
    print(f"Graph ID: {g.identifier} has {len(g)} triples")
# Out:
# Graph ID: urn:x-rdflib:default has 0 triples
# Graph ID: ancestors-model.ttl has 22 triples
# Graph ID: ancestors-data.ttl has 9 triples

# %%
from rdflib import URIRef

for t in ds.quads((None, None, None, URIRef(DATA_FILES[0].name))):
    print(t)
# Out:
# (rdflib.term.URIRef('http://example.org/ancestor/Eve'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/ancestor/Person'), rdflib.term.URIRef('ancestors-data.ttl'))
# (rdflib.term.URIRef('http://example.org/ancestor/Alice'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/ancestor/Person'), rdflib.term.URIRef('ancestors-data.ttl'))
# (rdflib.term.URIRef('http://example.org/ancestor/Bob'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/ancestor/Person'), rdflib.term.URIRef('ancestors-data.ttl'))
# (rdflib.term.URIRef('http://example.org/ancestor/Alice'), rdflib.term.URIRef('http://example.org/ancestor/parentOf'), rdflib.term.URIRef('http://example.org/ancestor/Carol'), rdflib.term.URIRef('ancestors-data.ttl'))
# (rdflib.term.URIRef('http://example.org/ancestor/Carol'), rdflib.term.URIRef('http://example.org/ancestor/parentOf'), rdflib.term.URIRef('http://example.org/ancestor/Eve'), rdflib.term.URIRef('ancestors-data.ttl'))
# (rdflib.term.URIRef('http://example.org/ancestor/Carol'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/ancestor/Person'), rdflib.term.URIRef('ancestors-data.ttl'))
# (rdflib.term.URIRef('http://example.org/ancestor/Alice'), rdflib.term.URIRef('http://example.org/ancestor/parentOf'), rdflib.term.URIRef('http://example.org/ancestor/Bob'), rdflib.term.URIRef('ancestors-data.ttl'))
# (rdflib.term.URIRef('http://example.org/ancestor/David'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://example.org/ancestor/Person'), rdflib.term.URIRef('ancestors-data.ttl'))
# (rdflib.term.URIRef('http://example.org/ancestor/Bob'), rdflib.term.URIRef('http://example.org/ancestor/parentOf'), rdflib.term.URIRef('http://example.org/ancestor/David'), rdflib.term.URIRef('ancestors-data.ttl'))
